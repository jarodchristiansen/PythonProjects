# %% [markdown]
# <a href="https://colab.research.google.com/github/jarodchristiansen/PythonProjects/blob/master/GPT_2_Working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-gpt-2
# Out:
# ...
#   Created wheel for keras-gpt-2: filename=keras_gpt_2-0.15.0-cp36-none-any.whl size=10526 sha256=bf73cea383589348cf27677bca954f04e9ae3dc24461de77e5533cd26ec1f858
#   Stored in directory: /root/.cache/pip/wheels/c5/b3/c7/fb39496446fc6493380fe3983788cc2dae979acdf3d00ee97f
# ...
#   Created wheel for keras-transformer: filename=keras_transformer-0.38.0-cp36-none-any.whl size=12942 sha256=e2473967c164df5719295676895ec0685d852f088908fa5a5e1c706a1f4672be
#   Stored in directory: /root/.cache/pip/wheels/e5/fb/3a/37b2b9326c799aa010ae46a04ddb04f320d8c77c0b7e837f4e
# ...
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.11.0-cp36-none-any.whl size=7554 sha256=fbd7e8e66e94ba52328ca2c86e6ea345d95bad013826199c2f3128246236fa58
#   Stored in directory: /root/.cache/pip/wheels/5b/a1/a0/ce6b1d49ba1a9a76f592e70cf297b05c96bc9f418146761032
# ...

# %%
import os
from keras_gpt_2 import load_trained_model_from_checkpoint, get_bpe_from_files, generate


model_folder = '/content/drive/My Drive/horror_models/355M'
config_path = os.path.join(model_folder, 'hparams.json')
checkpoint_path = os.path.join(model_folder, 'model.ckpt')
encoder_path = os.path.join(model_folder, 'encoder.json')
vocab_path = os.path.join(model_folder, 'vocab.bpe')

print('Load model from checkpoint...')
model = load_trained_model_from_checkpoint(config_path, checkpoint_path)
print('Load BPE from files...')
bpe = get_bpe_from_files(encoder_path, vocab_path)
# Out:
# Using TensorFlow backend.
# Load model from checkpoint...
# Load BPE from files...

# %%
import pandas as pd

# %%
print('Generate text...')
output = generate(model, bpe, ['The Darkest Day'], length=1000, top_k=3)

# If you are using the 117M model and top_k equals to 1, then the result will be:
# "From the day forth, my arm was broken, and I was in a state of pain. I was in a state of pain,"
print(output[0])

# %%
results = []
story = []

# %%
prompts = ['The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day',
           'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 'The Darkest Day', 
           'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory',
           'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 'Escaping Pergatory', 
           'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back',
           'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back', 'The Darkness Stared Back',
           ]

for i in prompts:
  story.append(i)
  output = generate(model, bpe, [i], length=1000, top_k=3)
  results.append(output[0])

# %%
len(results)
# Out:
# 108

# %%
len(results)
# Out:
# 72

# %%
for i in prompts:
  story.append(i)

# %%
len(story)
# Out:
# 72

# %%
new_data = pd.DataFrame()

# %%
new_data['Story'] = story
new_data['Text'] = results

# %%
new_data.to_csv('Horror_Stories_108k.csv')

# %%
data100k = pd.read_csv('/content/drive/My Drive/Horror_Stories_108k.csv')

# %%
data100k
# Out:
#      Unnamed: 0  ...                                               Text
# 0             0  ...  The Darkest Day\n\nA darkening world\n\nThe wo...
# 1             1  ...  The Darkest Day", "Dawn of a New Day" and "A N...
# 2             2  ...  The Darkest Day", the film's title track is th...
# 3             3  ...  The Darkest Day" is the third film of the seri...
# 4             4  ...  The Darkest Day"\n\nThe first of the four "dar...
# ..          ...  ...                                                ...
# 103         103  ...  The Darkness Stared Back" (1973).\n\nThe Dark ...
# 104         104  ...  The Darkness Stared Back at Him, and I Said, '...
# 105         105  ...  The Darkness Stared Back" (The Dark Side of Th...
# 106         106  ...  The Darkness Stared Back at Me\n"The Dark Lord...
# 107         107  ...  The Darkness Stared Back\nI've always wanted t...
#
# [108 rows x 3 columns]

# %%
darkest_day = data100k.loc[data100k['Story'] == 'The Darkest Day']
escaping_pergatory = data100k.loc[data100k['Story'] == 'Escaping Pergatory']
darkness = data100k.loc[data100k['Story'] == 'The Darkness Stared Back']

# %%
darkness
# Out:
#      Unnamed: 0  ...                                               Text
# 36           36  ...  The Darkness Stared Back at Us"\n"We Are The K...
# 37           37  ...  The Darkness Stared Back at Us\n\nI'm sure tha...
# 38           38  ...  The Darkness Stared Back\n\nI was in the middl...
# 39           39  ...  The Darkness Stared Back at Me" (1957), and "I...
# 40           40  ...  The Darkness Stared Back at Me" (The Dark Knig...
# 41           41  ...  The Darkness Stared Back\n\n"The Darkness star...
# 42           42  ...  The Darkness Stared Back" (The Darkness Stares...
# 43           43  ...  The Darkness Stared Back at Us, and the Darkne...
# 44           44  ...  The Darkness Stared Back at Us, and the Night ...
# 45           45  ...  The Darkness Stared Back" (The Dark Side Of Li...
# 46           46  ...  The Darkness Stared Back at Him, And He Was St...
# 47           47  ...  The Darkness Stared Back\nThe darkness stared ...
# ...

# %%
escaping_pergatory
# Out:
#     Unnamed: 0  ...                                               Text
# 18          18  ...  Escaping Pergatory, the most common way of get...
# 19          19  ...  Escaping Pergatory: A Guide To Surviving A Pri...
# 20          20  ...  Escaping Pergatory\n\nIn order not to get trap...
# 21          21  ...  Escaping Pergatory, a small town in the north-...
# 22          22  ...  Escaping Pergatory\n\nA perceptive observer wi...
# 23          23  ...  Escaping Pergatory: The New York City Transit ...
# 24          24  ...  Escaping Pergatory, the most dangerous area of...
# 25          25  ...  Escaping Pergatory, and the Enduring Mystery o...
# 26          26  ...  Escaping Pergatory\n"We are not here for a pol...
# 27          27  ...  Escaping Pergatory: The "Gang of Four", who we...
# 28          28  ...  Escaping Pergatory: The "Cave of Death"\n\nThe...
# 29          29  ...  Escaping Pergatory, and a number of others tha...
# ...

# %%
darkest_day
# Out:
#     Unnamed: 0  ...                                               Text
# 0            0  ...  The Darkest Day\n\nA darkening world\n\nThe wo...
# 1            1  ...  The Darkest Day", "Dawn of a New Day" and "A N...
# 2            2  ...  The Darkest Day", the film's title track is th...
# 3            3  ...  The Darkest Day" is the third film of the seri...
# 4            4  ...  The Darkest Day"\n\nThe first of the four "dar...
# 5            5  ...  The Darkest Day", "The Darkest Night", etc.\n\...
# 6            6  ...  The Darkest Day", and the film's title track.\...
# 7            7  ...  The Darkest Day\nThe first thing I want you al...
# 8            8  ...  The Darkest Day" and The Day of the Doctor (19...
# 9            9  ...  The Darkest Day\n\nThe dark side of the Moon\n...
# 10          10  ...  The Darkest Day", and "The Last of Us", which ...
# 11          11  ...  The Darkest Day" is an epic fantasy series tha...
# ...

# %%
with open('Darkest_Day_part1.txt', 'w') as filehandle:
    for i in darkest_day['Text'][0:2]:
        filehandle.write('%s\n' % i)

# %%
# !pip install language-tool-python

# %%
darkest_day['Text'][0]
# Out:
# str

# %%
import language_tool_python
tool = language_tool_python.LanguageTool('en-US')
# Out:
# ...
# Unzipping /tmp/tmpw_iyp4cs.zip to /root/.cache/language_tool_python/.
# Downloaded https://www.languagetool.org/download/LanguageTool-4.9.zip to /root/.cache/language_tool_python/.
# self._url: http://127.0.0.1:8081/v2/

# %%
import language_tool_python
tool = language_tool_python.LanguageTool('en-US')
# Out:
# self._url: http://127.0.0.1:8083/v2/
# ...

# %%
import time

# %%
darkest_day_grammar = []
escaping_grammar = []

for i in darkest_day['Text']:
  matches = tool.check(i)
  darkest_day_grammar.append(tool.correct(i))

for i in escaping_pergatory['Text']:
  matches = tool.check(i)
  escaping_grammar.append(tool.correct(i))

# %%
darkest_day
# Out:
#     Unnamed: 0  ...                                               Text
# 0            0  ...  The Darkest Day\n\nA darkening world\n\nThe wo...
# 1            1  ...  The Darkest Day", "Dawn of a New Day" and "A N...
# 2            2  ...  The Darkest Day", the film's title track is th...
# 3            3  ...  The Darkest Day" is the third film of the seri...
# 4            4  ...  The Darkest Day"\n\nThe first of the four "dar...
# 5            5  ...  The Darkest Day", "The Darkest Night", etc.\n\...
# 6            6  ...  The Darkest Day", and the film's title track.\...
# 7            7  ...  The Darkest Day\nThe first thing I want you al...
# 8            8  ...  The Darkest Day" and The Day of the Doctor (19...
# 9            9  ...  The Darkest Day\n\nThe dark side of the Moon\n...
# 10          10  ...  The Darkest Day", and "The Last of Us", which ...
# 11          11  ...  The Darkest Day" is an epic fantasy series tha...
# ...

# %%
grammared_darkest = pd.DataFrame()
grammared_darkest['Copy'] = darkest_day_grammar

grammared_escape = pd.DataFrame()
grammared_escape['Copy'] = escaping_grammar

# %%
grammared_darkest.to_csv('The Darkest Day_2.csv')

grammared_escape.to_csv('Escaping Purgatory_2.csv')

# %%
# !mkdir horror_story_csvs_1
